# %%
import os
import re
import sys
import numpy as np
from scipy.sparse import hstack
import time
import pandas as pd
from nltk.stem.snowball import SnowballStemmer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, accuracy_score , recall_score , precision_score
import lightgbm as lgb
import wordbatch
from wordbatch.extractors import WordBag, WordHash
from nltk.corpus import stopwords
import pickle as pkl
import gzip

# %%
stemmer = SnowballStemmer("english")

# Define helpers for text normalization
stopwords = {x: 1 for x in stopwords.words('english')}
non_alphanums = re.compile(u'[^A-Za-z0-9]+')

def rmsle(y, y0):
    assert len(y) == len(y0)
    return np.sqrt(np.mean(np.power(np.log1p(y) - np.log1p(y0), 2)))

def normalize_text(text):
    return u" ".join(
        [x for x in [y for y in non_alphanums.sub(' ', text).lower().strip().split(" ")] \
         if len(x) > 1 and x not in stopwords])

# %%
train = pd.read_csv('./data/kaggle/train.csv')
test = pd.read_csv('./data/kaggle/test.csv')

train_size = train.shape[0]
y = train['label']
test_ids = test['id']
test_size = test.shape[0]

# %%
train.drop('label', axis=1, inplace=True)

# %%
df = train.append(test)
df.shape
# Out:
# (26000, 4)

# %%
df.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1  Ever get the feeling your life circles the rou...
# 2  Why the Truth Might Get You Fired October 29, ...
# 3  Videos 15 Civilians Killed In Single US Airstr...
# 4  Print \r\nAn Iranian woman has been sentenced ...

# %%
# fill nans
print("Filling NaNs")
df['author'].fillna('No author', inplace=True)
df['title'].fillna('No title', inplace=True)
df['text'].fillna('No text', inplace=True)
# Out:
# Filling NaNs

# %%
print("Start Encoding Labels for Author")
le = LabelEncoder()
df['author_cat'] = le.fit_transform(df['author'])
df.head()
# Out:
# Start Encoding Labels for Author
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  author_cat
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...        1062
# 1  Ever get the feeling your life circles the rou...        1026
# 2  Why the Truth Might Get You Fired October 29, ...         940
# 3  Videos 15 Civilians Killed In Single US Airstr...        2020
# 4  Print \r\nAn Iranian woman has been sentenced ...        1701

# %%
print("Start Stemming Title")
df['stemmed_title'] = df['title'].map(lambda x: ' '.join([stemmer.stem(y) for y in x.split(' ')]))

print("Start Stemming News Text")
df['stemmed_text'] = df['text'].map(lambda x: ' '.join([stemmer.stem(y) for y in x.split(' ')]))
# Out:
# Start Stemming Title
# Start Stemming News Text

# %%
authors_df = df[['author', 'author_cat']]
authors_df.head()
# Out:
#                author  author_cat
# 0       Darrell Lucus        1062
# 1     Daniel J. Flynn        1026
# 2  Consortiumnews.com         940
# 3     Jessica Purkiss        2020
# 4      Howard Portnoy        1701

# %%
authors_df.to_csv('./data/author_cat_kaggle.csv', index=False)

# %%
# drop the title autor and text
df.drop(['id', 'title', 'author', 'text'], axis=1, inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-5fb73c30a5f6> in <module>
#       1 # drop the title autor and text
# ----> 2 df.drop(['id', 'title', 'author', 'text'], axis=1, inplace=True)
#       3
#       4 df.head()
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "['title' 'author' 'text'] not found in axis"

# %%
df.drop(['id'], axis=1, inplace=True)

# %%
wb = wordbatch.WordBatch(normalize_text
                         , extractor=(WordBag, {"hash_ngrams": 2,
                                                "hash_ngrams_weights": [0.5, -1.0],
                                                "hash_size": 2 ** 23,
                                                "norm": 'l2',
                                                "tf": 'log',
                                                "idf": 50.0}
                                     )
                         , procs=8
                         , method="serial")

wb.dictionary_freeze = True

# %%
X_title = wb.transform(df['stemmed_title'])
X_text = wb.transform(df['stemmed_text'])
X_author = df['author_cat'].values
X_author = X_author.reshape(-1, 1)
sparse_merge = hstack((X_title, X_text, X_author)).tocsr()
# Out:
# Normalize text
# Extract wordbags
# Normalize text
# Extract wordbags

# %%
sparse_merge.shape
# Out:
# (26000, 16777217)

# %%
X = sparse_merge[:train_size]
X_test = sparse_merge[train_size:]
train_X, valid_X, train_y, valid_y = train_test_split(X, y, test_size=0.05, random_state=100)
d_train = lgb.Dataset(train_X, label=train_y)
d_valid = lgb.Dataset(valid_X, label=valid_y)
watchlist = [d_train, d_valid]

# %%
params = {
        'objective': 'binary',
        'learning_rate': 0.4,
        'num_leaves': 31,
        'feature_fraction': 0.64,
        'bagging_fraction': 0.8,
        'bagging_freq': 1,
        'boosting_type': 'gbdt',
        'metric': 'binary_logloss'
    }

model = lgb.train(params, train_set=d_train, num_boost_round=6000, valid_sets=watchlist,
                      early_stopping_rounds=1000, verbose_eval=1)
# Out:
# [1]	training's binary_logloss: 0.403742	valid_1's binary_logloss: 0.409301
# Training until validation scores don't improve for 1000 rounds.
# [2]	training's binary_logloss: 0.266459	valid_1's binary_logloss: 0.270318
# [3]	training's binary_logloss: 0.197907	valid_1's binary_logloss: 0.20503
# [4]	training's binary_logloss: 0.152899	valid_1's binary_logloss: 0.162766
# [5]	training's binary_logloss: 0.119917	valid_1's binary_logloss: 0.126612
# [6]	training's binary_logloss: 0.0933714	valid_1's binary_logloss: 0.0968885
# [7]	training's binary_logloss: 0.0759055	valid_1's binary_logloss: 0.0814135
# [8]	training's binary_logloss: 0.0619906	valid_1's binary_logloss: 0.0690455
# [9]	training's binary_logloss: 0.0522674	valid_1's binary_logloss: 0.0589304
# [10]	training's binary_logloss: 0.0445224	valid_1's binary_logloss: 0.0511324
# [11]	training's binary_logloss: 0.0388735	valid_1's binary_logloss: 0.0490104
# [12]	training's binary_logloss: 0.0329797	valid_1's binary_logloss: 0.0439316
# [13]	training's binary_logloss: 0.0278507	valid_1's binary_logloss: 0.0404511
# [14]	training's binary_logloss: 0.0234104	valid_1's binary_logloss: 0.0361426
# [15]	training's binary_logloss: 0.0204878	valid_1's binary_logloss: 0.0319148
# [16]	training's binary_logloss: 0.017486	valid_1's binary_logloss: 0.0301002
# [17]	training's binary_logloss: 0.0152559	valid_1's binary_logloss: 0.0299196
# [18]	training's binary_logloss: 0.0131137	valid_1's binary_logloss: 0.0261179
# [19]	training's binary_logloss: 0.0115532	valid_1's binary_logloss: 0.0240131
# [20]	training's binary_logloss: 0.00998453	valid_1's binary_logloss: 0.0224872
# [21]	training's binary_logloss: 0.00868975	valid_1's binary_logloss: 0.0208372
# [22]	training's binary_logloss: 0.00757518	valid_1's binary_logloss: 0.0198953
# [23]	training's binary_logloss: 0.00662154	valid_1's binary_logloss: 0.0188799
# [24]	training's binary_logloss: 0.00593972	valid_1's binary_logloss: 0.0182758
# [25]	training's binary_logloss: 0.0052971	valid_1's binary_logloss: 0.018287
# [26]	training's binary_logloss: 0.00473397	valid_1's binary_logloss: 0.0166995
# [27]	training's binary_logloss: 0.0042549	valid_1's binary_logloss: 0.0161741
# [28]	training's binary_logloss: 0.00377904	valid_1's binary_logloss: 0.0156033
# [29]	training's binary_logloss: 0.00338715	valid_1's binary_logloss: 0.0158104
# [30]	training's binary_logloss: 0.00298818	valid_1's binary_logloss: 0.0146978
# [31]	training's binary_logloss: 0.00271106	valid_1's binary_logloss: 0.0136367
# [32]	training's binary_logloss: 0.00244256	valid_1's binary_logloss: 0.0137525
# [33]	training's binary_logloss: 0.00217004	valid_1's binary_logloss: 0.0141488
# [34]	training's binary_logloss: 0.00195196	valid_1's binary_logloss: 0.0145284
# [35]	training's binary_logloss: 0.00175081	valid_1's binary_logloss: 0.0130071
# [36]	training's binary_logloss: 0.00158486	valid_1's binary_logloss: 0.0133002
# [37]	training's binary_logloss: 0.00146269	valid_1's binary_logloss: 0.0131392
# [38]	training's binary_logloss: 0.00129396	valid_1's binary_logloss: 0.0127401
# [39]	training's binary_logloss: 0.0011585	valid_1's binary_logloss: 0.0120497
# [40]	training's binary_logloss: 0.00105187	valid_1's binary_logloss: 0.0113569
# [41]	training's binary_logloss: 0.000969412	valid_1's binary_logloss: 0.0115221
# [42]	training's binary_logloss: 0.000898615	valid_1's binary_logloss: 0.0109322
# [43]	training's binary_logloss: 0.000844229	valid_1's binary_logloss: 0.0103081
# [44]	training's binary_logloss: 0.000794205	valid_1's binary_logloss: 0.0108126
# [45]	training's binary_logloss: 0.000720665	valid_1's binary_logloss: 0.0109323
# [46]	training's binary_logloss: 0.000694551	valid_1's binary_logloss: 0.0110835
# [47]	training's binary_logloss: 0.000667308	valid_1's binary_logloss: 0.0110395
# [48]	training's binary_logloss: 0.000633757	valid_1's binary_logloss: 0.0106469
# [49]	training's binary_logloss: 0.000582278	valid_1's binary_logloss: 0.0102368
# [50]	training's binary_logloss: 0.000571088	valid_1's binary_logloss: 0.0101062
# [51]	training's binary_logloss: 0.000556754	valid_1's binary_logloss: 0.00988581
# [52]	training's binary_logloss: 0.000548013	valid_1's binary_logloss: 0.010341
# [53]	training's binary_logloss: 0.000503617	valid_1's binary_logloss: 0.0099603
# [54]	training's binary_logloss: 0.000499382	valid_1's binary_logloss: 0.0102033
# [55]	training's binary_logloss: 0.000498522	valid_1's binary_logloss: 0.0106544
# [56]	training's binary_logloss: 0.0246334	valid_1's binary_logloss: 0.043609
# [57]	training's binary_logloss: 0.171446	valid_1's binary_logloss: 0.242658
# [58]	training's binary_logloss: 0.89663	valid_1's binary_logloss: 1.04034
# [59]	training's binary_logloss: 0.713445	valid_1's binary_logloss: 1.1544
# [60]	training's binary_logloss: 0.908355	valid_1's binary_logloss: 1.43428
# [61]	training's binary_logloss: 0.731098	valid_1's binary_logloss: 1.17438
# [62]	training's binary_logloss: 0.752854	valid_1's binary_logloss: 1.03879
# [63]	training's binary_logloss: 0.711374	valid_1's binary_logloss: 0.993788
# [64]	training's binary_logloss: 1.0637	valid_1's binary_logloss: 1.25289
# [65]	training's binary_logloss: 1.23008	valid_1's binary_logloss: 1.53289
# [66]	training's binary_logloss: 1.36989	valid_1's binary_logloss: 1.63197
# [67]	training's binary_logloss: 1.50959	valid_1's binary_logloss: 1.92245
	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [956]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [957]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [958]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [959]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [960]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [961]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [962]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [963]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [964]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [965]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [966]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [967]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [968]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [969]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [970]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [971]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [972]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [973]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [974]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [975]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [976]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [977]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [978]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [979]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [980]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [981]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [982]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [983]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [984]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [985]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [986]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [987]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [988]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [989]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [990]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [991]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [992]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [993]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [994]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [995]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [996]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [997]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [998]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [999]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1000]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1001]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1002]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1003]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1004]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1005]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1006]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1007]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1008]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1009]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1010]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1011]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1012]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1013]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1014]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1015]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1016]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1017]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1018]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1019]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1020]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1021]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1022]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1023]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1024]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1025]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1026]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1027]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1028]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1029]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1030]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1031]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1032]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1033]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1034]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1035]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1036]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1037]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1038]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1039]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1040]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1041]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1042]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1043]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1044]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1045]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1046]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1047]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1048]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1049]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1050]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# [1051]	training's binary_logloss: 13.7268	valid_1's binary_logloss: 13.4834
# Early stopping, best iteration is:
# [51]	training's binary_logloss: 0.000556754	valid_1's binary_logloss: 0.00988581

# %%
preds = model.predict(valid_X)
print("LGB dev f1_score:", f1_score(valid_y, np.round(preds)))
print("LGB dev accuracy_score:", accuracy_score(valid_y, np.round(preds)))
print("LGB dev recall_score:", recall_score(valid_y, np.round(preds)))
print("LGB dev precision_score:", precision_score(valid_y, np.round(preds)))
# Out:
# LGB dev f1_score: 0.9961013645224172
# LGB dev accuracy_score: 0.9961538461538462
# LGB dev recall_score: 0.998046875
# LGB dev precision_score: 0.9941634241245136

# %%
print('Saving model...')
# save model to file
if not os.path.exists('data/models/'):
    os.makedirs('data/models/')

model.save_model('data/models/lgb_model_best_iter_2.txt', num_iteration=model.best_iteration)
print('Model Saved')
# Out:
# Saving model...
# Model Saved

# %%
print("Saving wb model")
with open('data/models/wb_transform.pkl', 'wb') as model_file:
    pkl.dump(wb, model_file, protocol=2)
print('Model Saved')
# Out:
# Saving wb model
# Model Saved

# %%
y_hat = model.predict(X_test)
pred = pd.DataFrame(np.round(y_hat).astype(int), columns=['label'])
pred['id'] = test_ids
pred.to_csv('data/kaggle/submission_lgb_simple_2.csv', index=False)
print('Kaggle Submission Saved to data/kaggle/')
# Out:
# Kaggle Submission Saved to data/kaggle/

# %% [markdown]
# # now lets build a simple example to test a client version

# %%
gbm = lgb.Booster(model_file='./data/models/lgb_model_best_iter.txt')

print("Loading models")
pickle_model = "./data/models/wb_transform.pkl"
wb_t = pkl.load(open(pickle_model, 'rb'))
# Out:
# Loading models

# %%
gbm

# %%
wb_t

# %%
#author_cat	stemmed_title	stemmed_text
d = {'stemmed_title': train['title'][1],
     'stemmed_text': train['text'][1],
     'author_cat': 1026}

# %%
X_test_title = wb.transform([d['stemmed_title']])
X_test_title.shape
# Out:
# Normalize text
# Extract wordbags
# (1, 8388608)

# %%
X_test_text = wb.transform([d['stemmed_text']])
X_test_text.shape
# Out:
# Normalize text
# Extract wordbags
# (1, 8388608)

# %%
X_test_author = np.array(d['author_cat'])
X_test_author = X_test_author.reshape(-1, 1)
X_test_author.shape
# Out:
# (1, 1)

# %%
sparse_merge_test = hstack((X_test_title, X_test_text, X_test_author)).tocsr()
sparse_merge_test.shape
# Out:
# (1, 16777217)

# %%
pred = gbm.predict(sparse_merge_test)
pred
# Out:
# array([0.99802852])
