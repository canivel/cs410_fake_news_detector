# %%
import os
import re
import sys
import numpy as np
from scipy.sparse import hstack
import time
import pandas as pd
from nltk.stem.snowball import SnowballStemmer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, accuracy_score , recall_score , precision_score
import lightgbm as lgb
import wordbatch
from wordbatch.extractors import WordBag, WordHash
from nltk.corpus import stopwords
import pickle as pkl
import gzip

# %%
stemmer = SnowballStemmer("english")

# Define helpers for text normalization
stopwords = {x: 1 for x in stopwords.words('english')}
non_alphanums = re.compile(u'[^A-Za-z0-9]+')

def rmsle(y, y0):
    assert len(y) == len(y0)
    return np.sqrt(np.mean(np.power(np.log1p(y) - np.log1p(y0), 2)))

def normalize_text(text):
    return u" ".join(
        [x for x in [y for y in non_alphanums.sub(' ', text).lower().strip().split(" ")] \
         if len(x) > 1 and x not in stopwords])

# %%
train = pd.read_csv('data/df_final_v1.csv')
test = pd.read_csv('./data/kaggle/test.csv')

train_size = train.shape[0]
y = train['label']
test_ids = test['id']
test_size = test.shape[0]

# %%
train.shape
# Out:
# (54394, 3)

# %%
train.drop(['label'], axis=1, inplace=True)

# %%
test.drop(['id'], axis=1, inplace=True)

# %%
test.shape
# Out:
# (5200, 3)

# %%
df = train.append(test, sort=False)
df.shape
# Out:
# (59594, 3)

# %%
df.head()
# Out:
#                                                title              author  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1  Ever get the feeling your life circles the rou...
# 2  Why the Truth Might Get You Fired October 29, ...
# 3  Videos 15 Civilians Killed In Single US Airstr...
# 4  Print \r\nAn Iranian woman has been sentenced ...

# %%
# fill nans
print("Filling NaNs")
df['author'].fillna('No author', inplace=True)
df['title'].fillna('No title', inplace=True)
df['text'].fillna('No text', inplace=True)
# Out:
# Filling NaNs

# %%
print("Start Encoding Labels for Author")
le = LabelEncoder()
df['author_cat'] = le.fit_transform(df['author'])
df.head()
# Out:
# Start Encoding Labels for Author
#                                                title              author  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  author_cat
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...        2191
# 1  Ever get the feeling your life circles the rou...        2114
# 2  Why the Truth Might Get You Fired October 29, ...        1863
# 3  Videos 15 Civilians Killed In Single US Airstr...        4372
# 4  Print \r\nAn Iranian woman has been sentenced ...        3564

# %%
print("Start Stemming Title")
df['stemmed_title'] = df['title'].map(lambda x: ' '.join([stemmer.stem(y) for y in x.split(' ')]))

print("Start Stemming News Text")
df['stemmed_text'] = df['text'].map(lambda x: ' '.join([stemmer.stem(y) for y in x.split(' ')]))
# Out:
# Start Stemming Title
# Start Stemming News Text

# %%
authors_df = df[['author', 'author_cat']]
authors_df.head()
# Out:
#                author  author_cat
# 0       Darrell Lucus        2191
# 1     Daniel J. Flynn        2114
# 2  Consortiumnews.com        1863
# 3     Jessica Purkiss        4372
# 4      Howard Portnoy        3564

# %%
authors_df.to_csv('./data/author_cat.csv', index=False)

# %%
# drop the title autor and text
df.drop(['title', 'author', 'text'], axis=1, inplace=True)
df.head()
# Out:
#    author_cat                                      stemmed_title  \
# 0        2191  hous dem aide: we didn't even see comey letter...
# 1        2114  flynn: hillari clinton, big woman on campus - ...
# 2        1863                   whi the truth might get you fire
# 3        4372  15 civilian kill in singl us airstrik have bee...
# 4        3564  iranian woman jail for fiction unpublish stori...
#
#                                         stemmed_text
# 0  hous dem aide: we didn't even see comey letter...
# 1  ever get the feel your life circl the roundabo...
# 2  whi the truth might get you fire octob 29, 201...
# 3  video 15 civilian kill in singl us airstrik ha...
# 4  print \r\nan iranian woman has been sentenc to...

# %%
wb = wordbatch.WordBatch(normalize_text
                         , extractor=(WordBag, {"hash_ngrams": 2,
                                                "hash_ngrams_weights": [0.5, -1.0],
                                                "hash_size": 2 ** 23,
                                                "norm": 'l2',
                                                "tf": 'log',
                                                "idf": 10.0}
                                     )
                         , procs=8
                         , method="serial")

wb.dictionary_freeze = True

# %%
X_title = wb.transform(df['stemmed_title'])
X_text = wb.transform(df['stemmed_text'])
X_author = df['author_cat'].values
X_author = X_author.reshape(-1, 1)
sparse_merge = hstack((X_title, X_text, X_author)).tocsr()
# Out:
# Normalize text
# Extract wordbags
# Normalize text
# Extract wordbags

# %%
sparse_merge.shape
# Out:
# (59594, 16777217)

# %%
X = sparse_merge[:train_size]
X_test = sparse_merge[train_size:]
train_X, valid_X, train_y, valid_y = train_test_split(X, y, test_size=0.05, random_state=100)
d_train = lgb.Dataset(train_X, label=train_y)
d_valid = lgb.Dataset(valid_X, label=valid_y)
watchlist = [d_train, d_valid]

# %%
params = {
        'objective': 'binary',
        'learning_rate': 0.1,
        'num_leaves': 31,
        'feature_fraction': 0.64,
        'bagging_fraction': 0.8,
        'bagging_freq': 1,
        'boosting_type': 'gbdt',
        'metric': 'binary_logloss',
    
        'max_depth': 9,  # -1 means no limit
#         'min_child_samples': 100,  # Minimum number of data need in a child(min_data_in_leaf)
#         'max_bin': 100,  # Number of bucketed bin for feature values
#         'subsample': 0.7,  # Subsample ratio of the training instance.
#         'subsample_freq': 1,  # frequence of subsample, <=0 means no enable
#         'colsample_bytree': 0.9,  # Subsample ratio of columns when constructing each tree.
#         'min_child_weight': 0,  # Minimum sum of instance weight(hessian) needed in a child(leaf)
        'is_unbalance': True # because training data is unbalanced 
    }

model = lgb.train(params, train_set=d_train, num_boost_round=6000, valid_sets=watchlist,
                      early_stopping_rounds=200, verbose_eval=1)
# Out:
# [1]	training's binary_logloss: 0.609894	valid_1's binary_logloss: 0.605412
# Training until validation scores don't improve for 200 rounds.
# [2]	training's binary_logloss: 0.571572	valid_1's binary_logloss: 0.567641
# [3]	training's binary_logloss: 0.53593	valid_1's binary_logloss: 0.533766
# [4]	training's binary_logloss: 0.506498	valid_1's binary_logloss: 0.505747
# [5]	training's binary_logloss: 0.477199	valid_1's binary_logloss: 0.476518
# [6]	training's binary_logloss: 0.452367	valid_1's binary_logloss: 0.452325
# [7]	training's binary_logloss: 0.429476	valid_1's binary_logloss: 0.429777
# [8]	training's binary_logloss: 0.409893	valid_1's binary_logloss: 0.410734
# [9]	training's binary_logloss: 0.392695	valid_1's binary_logloss: 0.393961
# [10]	training's binary_logloss: 0.377166	valid_1's binary_logloss: 0.378443
# [11]	training's binary_logloss: 0.363674	valid_1's binary_logloss: 0.36577
# [12]	training's binary_logloss: 0.349547	valid_1's binary_logloss: 0.351409
# [13]	training's binary_logloss: 0.337522	valid_1's binary_logloss: 0.339315
# [14]	training's binary_logloss: 0.324863	valid_1's binary_logloss: 0.326804
# [15]	training's binary_logloss: 0.314591	valid_1's binary_logloss: 0.317431
# [16]	training's binary_logloss: 0.305937	valid_1's binary_logloss: 0.308708
# [17]	training's binary_logloss: 0.296751	valid_1's binary_logloss: 0.299095
# [18]	training's binary_logloss: 0.288257	valid_1's binary_logloss: 0.291381
# [19]	training's binary_logloss: 0.280485	valid_1's binary_logloss: 0.284082
# [20]	training's binary_logloss: 0.273106	valid_1's binary_logloss: 0.276954
# [21]	training's binary_logloss: 0.265938	valid_1's binary_logloss: 0.270134
# [22]	training's binary_logloss: 0.259264	valid_1's binary_logloss: 0.263982
# [23]	training's binary_logloss: 0.252307	valid_1's binary_logloss: 0.257247
# [24]	training's binary_logloss: 0.24687	valid_1's binary_logloss: 0.252261
# [25]	training's binary_logloss: 0.241799	valid_1's binary_logloss: 0.247576
# [26]	training's binary_logloss: 0.236664	valid_1's binary_logloss: 0.241965
# [27]	training's binary_logloss: 0.231894	valid_1's binary_logloss: 0.237269
# [28]	training's binary_logloss: 0.227142	valid_1's binary_logloss: 0.233043
# [29]	training's binary_logloss: 0.222284	valid_1's binary_logloss: 0.228728
# [30]	training's binary_logloss: 0.217391	valid_1's binary_logloss: 0.224073
# [31]	training's binary_logloss: 0.213146	valid_1's binary_logloss: 0.220016
# [32]	training's binary_logloss: 0.209221	valid_1's binary_logloss: 0.216148
# [33]	training's binary_logloss: 0.20367	valid_1's binary_logloss: 0.210534
# [34]	training's binary_logloss: 0.199943	valid_1's binary_logloss: 0.206399
# [35]	training's binary_logloss: 0.195964	valid_1's binary_logloss: 0.202809
# [36]	training's binary_logloss: 0.192507	valid_1's binary_logloss: 0.199448
# [37]	training's binary_logloss: 0.189304	valid_1's binary_logloss: 0.196158
# [38]	training's binary_logloss: 0.185417	valid_1's binary_logloss: 0.192311
# [39]	training's binary_logloss: 0.182146	valid_1's binary_logloss: 0.189181
# [40]	training's binary_logloss: 0.178897	valid_1's binary_logloss: 0.186193
# [41]	training's binary_logloss: 0.175849	valid_1's binary_logloss: 0.183673
# [42]	training's binary_logloss: 0.173451	valid_1's binary_logloss: 0.181741
# [43]	training's binary_logloss: 0.170465	valid_1's binary_logloss: 0.179059
# [44]	training's binary_logloss: 0.167731	valid_1's binary_logloss: 0.176643
# [45]	training's binary_logloss: 0.165277	valid_1's binary_logloss: 0.174279
# [46]	training's binary_logloss: 0.162508	valid_1's binary_logloss: 0.171823
# [47]	training's binary_logloss: 0.160303	valid_1's binary_logloss: 0.169766
# [48]	training's binary_logloss: 0.157801	valid_1's binary_logloss: 0.167228
# [49]	training's binary_logloss: 0.155758	valid_1's binary_logloss: 0.165405
# [50]	training's binary_logloss: 0.153613	valid_1's binary_logloss: 0.163272
# [51]	training's binary_logloss: 0.151561	valid_1's binary_logloss: 0.161589
# [52]	training's binary_logloss: 0.148996	valid_1's binary_logloss: 0.158962
# [53]	training's binary_logloss: 0.147035	valid_1's binary_logloss: 0.156917
# [54]	training's binary_logloss: 0.145158	valid_1's binary_logloss: 0.155341
# [55]	training's binary_logloss: 0.143273	valid_1's binary_logloss: 0.153469
# [56]	training's binary_logloss: 0.141551	valid_1's binary_logloss: 0.15208
# [57]	training's binary_logloss: 0.137486	valid_1's binary_logloss: 0.147493
# [58]	training's binary_logloss: 0.135749	valid_1's binary_logloss: 0.145894
# [59]	training's binary_logloss: 0.134314	valid_1's binary_logloss: 0.144555
# [60]	training's binary_logloss: 0.132355	valid_1's binary_logloss: 0.143057
# [61]	training's binary_logloss: 0.130808	valid_1's binary_logloss: 0.141665
# [62]	training's binary_logloss: 0.129231	valid_1's binary_logloss: 0.140295
# [63]	training's binary_logloss: 0.127547	valid_1's binary_logloss: 0.138835
# [64]	training's binary_logloss: 0.126176	valid_1's binary_logloss: 0.137512
# [65]	training's binary_logloss: 0.12449	valid_1's binary_logloss: 0.136256
# [66]	training's binary_logloss: 0.122972	valid_1's binary_logloss: 0.135118
# [67]	training's binary_logloss: 0.120596	valid_1's binary_logloss: 0.132524
# [68]	training's binary_logloss: 0.119146	valid_1's binary_logloss: 0.131597
# [69]	training's binary_logloss: 0.1178	valid_1's binary_logloss: 0.130415
# [70]	training's binary_logloss: 0.116471	valid_1's binary_logloss: 0.12948
# [71]	training's binary_logloss: 0.115103	valid_1's binary_logloss: 0.128289
# [72]	training's binary_logloss: 0.113745	valid_1's binary_logloss: 0.127378
# [73]	training's binary_logloss: 0.111129	valid_1's binary_logloss: 0.124438
# [74]	training's binary_logloss: 0.109957	valid_1's binary_logloss: 0.123589
# [75]	training's binary_logloss: 0.108725	valid_1's binary_logloss: 0.122423
# [76]	training's binary_logloss: 0.107464	valid_1's binary_logloss: 0.121273
# [77]	training's binary_logloss: 0.10632	valid_1's binary_logloss: 0.120339
# [78]	training's binary_logloss: 0.10514	valid_1's binary_logloss: 0.119059
# [79]	training's binary_logloss: 0.103885	valid_1's binary_logloss: 0.117923
# [80]	training's binary_logloss: 0.102689	valid_1's binary_logloss: 0.117106
# [81]	training's binary_logloss: 0.101861	valid_1's binary_logloss: 0.116371
# [82]	training's binary_logloss: 0.100957	valid_1's binary_logloss: 0.115568
# [83]	training's binary_logloss: 0.0999774	valid_1's binary_logloss: 0.114477
# [84]	training's binary_logloss: 0.0986923	valid_1's binary_logloss: 0.113612
# [85]	training's binary_logloss: 0.0977403	valid_1's binary_logloss: 0.112913
# [86]	training's binary_logloss: 0.0966791	valid_1's binary_logloss: 0.111768
# [87]	training's binary_logloss: 0.0956566	valid_1's binary_logloss: 0.111022
# [88]	training's binary_logloss: 0.0947562	valid_1's binary_logloss: 0.11009
# [89]	training's binary_logloss: 0.0937265	valid_1's binary_logloss: 0.109268
# [90]	training's binary_logloss: 0.092857	valid_1's binary_logloss: 0.108577
# [91]	training's binary_logloss: 0.0920582	valid_1's binary_logloss: 0.108027
# [92]	training's binary_logloss: 0.0911947	valid_1's binary_logloss: 0.107236
# [93]	training's binary_logloss: 0.0902535	valid_1's binary_logloss: 0.10644
# [94]	training's binary_logloss: 0.0895265	valid_1's binary_logloss: 0.105796
# [95]	training's binary_logloss: 0.0884428	valid_1's binary_logloss: 0.104941
# [96]	training's binary_logloss: 0.0874056	valid_1's binary_logloss: 0.103869
# [97]	training's binary_logloss: 0.08668	valid_1's binary_logloss: 0.103366
# [98]	training's binary_logloss: 0.085798	valid_1's binary_logloss: 0.102413
# [99]	training's binary_logloss: 0.0850975	valid_1's binary_logloss: 0.101916
# [100]	training's binary_logloss: 0.0836132	valid_1's binary_logloss: 0.100116
# [101]	training's binary_logloss: 0.0828824	valid_1's binary_logloss: 0.0998658
# [102]	training's binary_logloss: 0.0821079	valid_1's binary_logloss: 0.0994472
# [103]	training's binary_logloss: 0.0813136	valid_1's binary_logloss: 0.0986511
# [104]	training's binary_logloss: 0.0805854	valid_1's binary_logloss: 0.0980353
# [105]	training's binary_logloss: 0.0797637	valid_1's binary_logloss: 0.0974574
# [106]	training's binary_logloss: 0.0790501	valid_1's binary_logloss: 0.0968419
# [107]	training's binary_logloss: 0.0781634	valid_1's binary_logloss: 0.0961083
# [108]	training's binary_logloss: 0.0775986	valid_1's binary_logloss: 0.0954625
# [109]	training's binary_logloss: 0.0769403	valid_1's binary_logloss: 0.0948333
# [110]	training's binary_logloss: 0.0761192	valid_1's binary_logloss: 0.0940741
# [111]	training's binary_logloss: 0.0753154	valid_1's binary_logloss: 0.0934944
# [112]	training's binary_logloss: 0.0747596	valid_1's binary_logloss: 0.0927618
# [113]	training's binary_logloss: 0.0741948	valid_1's binary_logloss: 0.0923576
# [114]	training's binary_logloss: 0.0735067	valid_1's binary_logloss: 0.0917102
# [115]	training's binary_logloss: 0.0729539	valid_1's binary_logloss: 0.0913187
# [116]	training's binary_logloss: 0.0722711	valid_1's binary_logloss: 0.0908207
# [117]	training's binary_logloss: 0.0718273	valid_1's binary_logloss: 0.0904638
# [118]	training's binary_logloss: 0.07105	valid_1's binary_logloss: 0.0898472
# [119]	training's binary_logloss: 0.0704994	valid_1's binary_logloss: 0.0894365
# [120]	training's binary_logloss: 0.0698952	valid_1's binary_logloss: 0.0888613
# [121]	training's binary_logloss: 0.0693186	valid_1's binary_logloss: 0.0885137
# [122]	training's binary_logloss: 0.0687761	valid_1's binary_logloss: 0.0879857
# [123]	training's binary_logloss: 0.0682255	valid_1's binary_logloss: 0.0874664
# [124]	training's binary_logloss: 0.0675976	valid_1's binary_logloss: 0.0871899
# [125]	training's binary_logloss: 0.0670955	valid_1's binary_logloss: 0.0867613
# [126]	training's binary_logloss: 0.0665381	valid_1's binary_logloss: 0.0862959
# [127]	training's binary_logloss: 0.0659989	valid_1's binary_logloss: 0.0855648
# [128]	training's binary_logloss: 0.0654911	valid_1's binary_logloss: 0.0853523
# [129]	training's binary_logloss: 0.0648741	valid_1's binary_logloss: 0.0848762
# [130]	training's binary_logloss: 0.0640987	valid_1's binary_logloss: 0.0841643
# [131]	training's binary_logloss: 0.0636027	valid_1's binary_logloss: 0.0837009
# [132]	training's binary_logloss: 0.0631612	valid_1's binary_logloss: 0.0833635
# [133]	training's binary_logloss: 0.0625926	valid_1's binary_logloss: 0.082872
# [134]	training's binary_logloss: 0.0620743	valid_1's binary_logloss: 0.0824385
# [135]	training's binary_logloss: 0.061585	valid_1's binary_logloss: 0.0820156
# [136]	training's binary_logloss: 0.060878	valid_1's binary_logloss: 0.081417
# [137]	training's binary_logloss: 0.0603782	valid_1's binary_logloss: 0.0807875
# [138]	training's binary_logloss: 0.059641	valid_1's binary_logloss: 0.0800169
# [139]	training's binary_logloss: 0.0591978	valid_1's binary_logloss: 0.0796496
# [140]	training's binary_logloss: 0.0587301	valid_1's binary_logloss: 0.0791454
# [141]	training's binary_logloss: 0.0582871	valid_1's binary_logloss: 0.0787712
# [142]	training's binary_logloss: 0.0579224	valid_1's binary_logloss: 0.0785083
# [143]	training's binary_logloss: 0.057549	valid_1's binary_logloss: 0.0781423
# [144]	training's binary_logloss: 0.0571247	valid_1's binary_logloss: 0.0779135
# [145]	training's binary_logloss: 0.0566336	valid_1's binary_logloss: 0.0773037
# [146]	training's binary_logloss: 0.0561577	valid_1's binary_logloss: 0.0770238
# [147]	training's binary_logloss: 0.0556336	valid_1's binary_logloss: 0.0766144
# [148]	training's binary_logloss: 0.0551874	valid_1's binary_logloss: 0.0763248
# [149]	training's binary_logloss: 0.0545468	valid_1's binary_logloss: 0.075727
# [150]	training's binary_logloss: 0.0541845	valid_1's binary_logloss: 0.0755351
# [151]	training's binary_logloss: 0.0537149	valid_1's binary_logloss: 0.0750895
# [152]	training's binary_logloss: 0.0533652	valid_1's binary_logloss: 0.0748776
# [153]	training's binary_logloss: 0.0530138	valid_1's binary_logloss: 0.0746502
# [154]	training's binary_logloss: 0.052649	valid_1's binary_logloss: 0.074482
# [155]	training's binary_logloss: 0.0522156	valid_1's binary_logloss: 0.0741993
# [156]	training's binary_logloss: 0.0518106	valid_1's binary_logloss: 0.0739631
# [157]	training's binary_logloss: 0.0514736	valid_1's binary_logloss: 0.073779
# [158]	training's binary_logloss: 0.0511175	valid_1's binary_logloss: 0.073559
# [159]	training's binary_logloss: 0.0506214	valid_1's binary_logloss: 0.0731056
# [160]	training's binary_logloss: 0.050167	valid_1's binary_logloss: 0.0724633
# [161]	training's binary_logloss: 0.0498479	valid_1's binary_logloss: 0.0719292
# [162]	training's binary_logloss: 0.0494212	valid_1's binary_logloss: 0.0717232
# [163]	training's binary_logloss: 0.0490425	valid_1's binary_logloss: 0.0715359
# [164]	training's binary_logloss: 0.0485586	valid_1's binary_logloss: 0.071074
# [165]	training's binary_logloss: 0.0481775	valid_1's binary_logloss: 0.0707098
# [166]	training's binary_logloss: 0.0479238	valid_1's binary_logloss: 0.0703825
# [167]	training's binary_logloss: 0.0476047	valid_1's binary_logloss: 0.0701013
# [168]	training's binary_logloss: 0.0471137	valid_1's binary_logloss: 0.0699242
# [169]	training's binary_logloss: 0.0467732	valid_1's binary_logloss: 0.0695907
# [170]	training's binary_logloss: 0.0464568	valid_1's binary_logloss: 0.0693491
# [171]	training's binary_logloss: 0.046187	valid_1's binary_logloss: 0.0692003
# [172]	training's binary_logloss: 0.045887	valid_1's binary_logloss: 0.0689044
# [173]	training's binary_logloss: 0.0455698	valid_1's binary_logloss: 0.0686835
# [174]	training's binary_logloss: 0.0451883	valid_1's binary_logloss: 0.0682388
# [175]	training's binary_logloss: 0.0444288	valid_1's binary_logloss: 0.0671918
# [176]	training's binary_logloss: 0.0440769	valid_1's binary_logloss: 0.0669605
# [177]	training's binary_logloss: 0.0438125	valid_1's binary_logloss: 0.0668636
# [178]	training's binary_logloss: 0.0434745	valid_1's binary_logloss: 0.06652
# [179]	training's binary_logloss: 0.0431876	valid_1's binary_logloss: 0.0662528
# [180]	training's binary_logloss: 0.042908	valid_1's binary_logloss: 0.0660765
# [181]	training's binary_logloss: 0.0426146	valid_1's binary_logloss: 0.0658216
# [182]	training's binary_logloss: 0.0422966	valid_1's binary_logloss: 0.065507
# [183]	training's binary_logloss: 0.0419585	valid_1's binary_logloss: 0.0652662
# [184]	training's binary_logloss: 0.0416742	valid_1's binary_logloss: 0.0652543
# [185]	training's binary_logloss: 0.0414062	valid_1's binary_logloss: 0.0651298
# [186]	training's binary_logloss: 0.0410811	valid_1's binary_logloss: 0.0648456
# [187]	training's binary_logloss: 0.0408499	valid_1's binary_logloss: 0.0646006
# [188]	training's binary_logloss: 0.0405661	valid_1's binary_logloss: 0.0645353
# [189]	training's binary_logloss: 0.0403116	valid_1's binary_logloss: 0.0643261
# [190]	training's binary_logloss: 0.0400764	valid_1's binary_logloss: 0.064057
# [191]	training's binary_logloss: 0.0398544	valid_1's binary_logloss: 0.0638946
# [192]	training's binary_logloss: 0.0395864	valid_1's binary_logloss: 0.0637655
# [193]	training's binary_logloss: 0.0393808	valid_1's binary_logloss: 0.0633824
# [194]	training's binary_logloss: 0.0391277	valid_1's binary_logloss: 0.0631839
# [195]	training's binary_logloss: 0.0389265	valid_1's binary_logloss: 0.0630229
# [196]	training's binary_logloss: 0.0386273	valid_1's binary_logloss: 0.0627786
# [197]	training's binary_logloss: 0.0382772	valid_1's binary_logloss: 0.0625389
# [198]	training's binary_logloss: 0.038082	valid_1's binary_logloss: 0.0621982
# [199]	training's binary_logloss: 0.0378815	valid_1's binary_logloss: 0.0621436
# [200]	training's binary_logloss: 0.0376764	valid_1's binary_logloss: 0.0619314
# [201]	training's binary_logloss: 0.0373433	valid_1's binary_logloss: 0.0614862
# [202]	training's binary_logloss: 0.0371018	valid_1's binary_logloss: 0.0612757
# [203]	training's binary_logloss: 0.0368683	valid_1's binary_logloss: 0.0610154
# [204]	training's binary_logloss: 0.0366351	valid_1's binary_logloss: 0.0608117
# [205]	training's binary_logloss: 0.0364405	valid_1's binary_logloss: 0.0606196
# [206]	training's binary_logloss: 0.0360693	valid_1's binary_logloss: 0.060275
# [207]	training's binary_logloss: 0.0358467	valid_1's binary_logloss: 0.0600074
# [208]	training's binary_logloss: 0.0355989	valid_1's binary_logloss: 0.0598735
# [209]	training's binary_logloss: 0.0353438	valid_1's binary_logloss: 0.0595958
# [210]	training's binary_logloss: 0.0351062	valid_1's binary_logloss: 0.0594334
# [211]	training's binary_logloss: 0.0347986	valid_1's binary_logloss: 0.0590734
# [212]	training's binary_logloss: 0.0345234	valid_1's binary_logloss: 0.0588115
# [213]	training's binary_logloss: 0.0343173	valid_1's binary_logloss: 0.0585508
# [214]	training's binary_logloss: 0.0340357	valid_1's binary_logloss: 0.0582575
# [215]	training's binary_logloss: 0.0337968	valid_1's binary_logloss: 0.0580571
# [216]	training's binary_logloss: 0.0335466	valid_1's binary_logloss: 0.058082
# [217]	training's binary_logloss: 0.0333204	valid_1's binary_logloss: 0.057887
# [218]	training's binary_logloss: 0.032946	valid_1's binary_logloss: 0.0574149
# [219]	training's binary_logloss: 0.0327757	valid_1's binary_logloss: 0.057268
# [220]	training's binary_logloss: 0.0325458	valid_1's binary_logloss: 0.0569788
# [221]	training's binary_logloss: 0.0322978	valid_1's binary_logloss: 0.0568257
# [222]	training's binary_logloss: 0.0320437	valid_1's binary_logloss: 0.0567807
# [223]	training's binary_logloss: 0.0318274	valid_1's binary_logloss: 0.0566768
# [224]	training's binary_logloss: 0.0315661	valid_1's binary_logloss: 0.0565325
# [225]	training's binary_logloss: 0.031259	valid_1's binary_logloss: 0.0562591
# [226]	training's binary_logloss: 0.0310816	valid_1's binary_logloss: 0.0560378
# [227]	training's binary_logloss: 0.0309518	valid_1's binary_logloss: 0.0559203
# [228]	training's binary_logloss: 0.0307433	valid_1's binary_logloss: 0.0557056
# [229]	training's binary_logloss: 0.0305983	valid_1's binary_logloss: 0.0554929
# [230]	training's binary_logloss: 0.0303726	valid_1's binary_logloss: 0.0553394
# [231]	training's binary_logloss: 0.0302129	valid_1's binary_logloss: 0.0551532
# [232]	training's binary_logloss: 0.0300034	valid_1's binary_logloss: 0.0550726
# [233]	training's binary_logloss: 0.0298549	valid_1's binary_logloss: 0.0549953
# [234]	training's binary_logloss: 0.0296469	valid_1's binary_logloss: 0.0550035
# [235]	training's binary_logloss: 0.0294072	valid_1's binary_logloss: 0.0550327
# [236]	training's binary_logloss: 0.0292173	valid_1's binary_logloss: 0.0549122
# [237]	training's binary_logloss: 0.0290854	valid_1's binary_logloss: 0.0548033
# [238]	training's binary_logloss: 0.0288518	valid_1's binary_logloss: 0.0545516
# [239]	training's binary_logloss: 0.0286709	valid_1's binary_logloss: 0.0544194
# [240]	training's binary_logloss: 0.0284143	valid_1's binary_logloss: 0.0540276
# [241]	training's binary_logloss: 0.0282296	valid_1's binary_logloss: 0.0538115
# [242]	training's binary_logloss: 0.0280934	valid_1's binary_logloss: 0.053589
# [243]	training's binary_logloss: 0.0279819	valid_1's binary_logloss: 0.0535245
# [244]	training's binary_logloss: 0.0278102	valid_1's binary_logloss: 0.0534553
# [245]	training's binary_logloss: 0.0276147	valid_1's binary_logloss: 0.0533147
# [246]	training's binary_logloss: 0.0274624	valid_1's binary_logloss: 0.0531884
# [247]	training's binary_logloss: 0.0273395	valid_1's binary_logloss: 0.0529876
# [248]	training's binary_logloss: 0.027134	valid_1's binary_logloss: 0.0528999
# [249]	training's binary_logloss: 0.0269518	valid_1's binary_logloss: 0.0527468
# [250]	training's binary_logloss: 0.0267649	valid_1's binary_logloss: 0.0526123
# [251]	training's binary_logloss: 0.026598	valid_1's binary_logloss: 0.052385
# [252]	training's binary_logloss: 0.0264642	valid_1's binary_logloss: 0.0522793
# [253]	training's binary_logloss: 0.0263456	valid_1's binary_logloss: 0.05215
# [254]	training's binary_logloss: 0.0261873	valid_1's binary_logloss: 0.0519595
# [255]	training's binary_logloss: 0.02599	valid_1's binary_logloss: 0.0518678
# [256]	training's binary_logloss: 0.0258614	valid_1's binary_logloss: 0.0517029
# [257]	training's binary_logloss: 0.0257064	valid_1's binary_logloss: 0.0514939
# [258]	training's binary_logloss: 0.0255907	valid_1's binary_logloss: 0.0513911
# [259]	training's binary_logloss: 0.0254594	valid_1's binary_logloss: 0.0512408
# [260]	training's binary_logloss: 0.0252928	valid_1's binary_logloss: 0.0510056
# [261]	training's binary_logloss: 0.0251609	valid_1's binary_logloss: 0.0509197
# [262]	training's binary_logloss: 0.0249991	valid_1's binary_logloss: 0.0508585
# [263]	training's binary_logloss: 0.0248401	valid_1's binary_logloss: 0.050831
# [264]	training's binary_logloss: 0.0246348	valid_1's binary_logloss: 0.0506327
# [265]	training's binary_logloss: 0.0245017	valid_1's binary_logloss: 0.0504881
# [266]	training's binary_logloss: 0.0243257	valid_1's binary_logloss: 0.0502222
# [267]	training's binary_logloss: 0.024132	valid_1's binary_logloss: 0.0500763
# [268]	training's binary_logloss: 0.0239829	valid_1's binary_logloss: 0.0499813
# [269]	training's binary_logloss: 0.023827	valid_1's binary_logloss: 0.0498471
# [270]	training's binary_logloss: 0.023723	valid_1's binary_logloss: 0.0497565
# [271]	training's binary_logloss: 0.023637	valid_1's binary_logloss: 0.0496941
# [272]	training's binary_logloss: 0.0233457	valid_1's binary_logloss: 0.0492479
# [273]	training's binary_logloss: 0.0231971	valid_1's binary_logloss: 0.0491217
# [274]	training's binary_logloss: 0.0230698	valid_1's binary_logloss: 0.0489398
# [275]	training's binary_logloss: 0.0229113	valid_1's binary_logloss: 0.0487714
# [276]	training's binary_logloss: 0.0227824	valid_1's binary_logloss: 0.0486505
# [277]	training's binary_logloss: 0.0226427	valid_1's binary_logloss: 0.0484479
# [278]	training's binary_logloss: 0.0225435	valid_1's binary_logloss: 0.04836
# [279]	training's binary_logloss: 0.0224405	valid_1's binary_logloss: 0.0482336
# [280]	training's binary_logloss: 0.0223224	valid_1's binary_logloss: 0.0481442
# [281]	training's binary_logloss: 0.0221921	valid_1's binary_logloss: 0.0481047
# [282]	training's binary_logloss: 0.0220616	valid_1's binary_logloss: 0.0480751
# [283]	training's binary_logloss: 0.0219535	valid_1's binary_logloss: 0.0479729
# [284]	training's binary_logloss: 0.0217921	valid_1's binary_logloss: 0.047793
# [285]	training's binary_logloss: 0.0216948	valid_1's binary_logloss: 0.0477331
# [286]	training's binary_logloss: 0.021489	valid_1's binary_logloss: 0.0473627
# [287]	training's binary_logloss: 0.0213911	valid_1's binary_logloss: 0.0472468
# [288]	training's binary_logloss: 0.0212436	valid_1's binary_logloss: 0.0470888
# [289]	training's binary_logloss: 0.0210958	valid_1's binary_logloss: 0.0469531
# [290]	training's binary_logloss: 0.0209593	valid_1's binary_logloss: 0.0468995
# [291]	training's binary_logloss: 0.0208544	valid_1's binary_logloss: 0.0467896
# [292]	training's binary_logloss: 0.020761	valid_1's binary_logloss: 0.0467442
# [293]	training's binary_logloss: 0.0206251	valid_1's binary_logloss: 0.046684
# [294]	training's binary_logloss: 0.0205315	valid_1's binary_logloss: 0.046604
# [295]	training's binary_logloss: 0.0204085	valid_1's binary_logloss: 0.0465547
# [296]	training's binary_logloss: 0.0202959	valid_1's binary_logloss: 0.0464512
# [297]	training's binary_logloss: 0.0201561	valid_1's binary_logloss: 0.0462195
# [298]	training's binary_logloss: 0.0200401	valid_1's binary_logloss: 0.0460404
# [299]	training's binary_logloss: 0.0199168	valid_1's binary_logloss: 0.0459683
# [300]	training's binary_logloss: 0.0197103	valid_1's binary_logloss: 0.0456739
# [301]	training's binary_logloss: 0.0196008	valid_1's binary_logloss: 0.0455471
# [302]	training's binary_logloss: 0.0195063	valid_1's binary_logloss: 0.0453872
# [303]	training's binary_logloss: 0.0194323	valid_1's binary_logloss: 0.0452879
# [304]	training's binary_logloss: 0.0192714	valid_1's binary_logloss: 0.0450537
# [305]	training's binary_logloss: 0.0191786	valid_1's binary_logloss: 0.0449621
# [306]	training's binary_logloss: 0.0190203	valid_1's binary_logloss: 0.0447841
# [307]	training's binary_logloss: 0.0189533	valid_1's binary_logloss: 0.0447076
# [308]	training's binary_logloss: 0.0188198	valid_1's binary_logloss: 0.0445477
# [309]	training's binary_logloss: 0.0186727	valid_1's binary_logloss: 0.0444876
# [310]	training's binary_logloss: 0.0185518	valid_1's binary_logloss: 0.0443808
# [311]	training's binary_logloss: 0.0184789	valid_1's binary_logloss: 0.0443697
# [312]	training's binary_logloss: 0.0183816	valid_1's binary_logloss: 0.0441887
# [313]	training's binary_logloss: 0.0183082	valid_1's binary_logloss: 0.0440943
# [314]	training's binary_logloss: 0.0181956	valid_1's binary_logloss: 0.0440303
# [315]	training's binary_logloss: 0.018106	valid_1's binary_logloss: 0.0440211
# [316]	training's binary_logloss: 0.0180125	valid_1's binary_logloss: 0.043969
# [317]	training's binary_logloss: 0.0179078	valid_1's binary_logloss: 0.0439415
# [318]	training's binary_logloss: 0.0178002	valid_1's binary_logloss: 0.0439528
# [319]	training's binary_logloss: 0.0177096	valid_1's binary_logloss: 0.0438002
# [320]	training's binary_logloss: 0.0176216	valid_1's binary_logloss: 0.0437534
# [321]	training's binary_logloss: 0.01753	valid_1's binary_logloss: 0.043713
# [322]	training's binary_logloss: 0.0174333	valid_1's binary_logloss: 0.0435608
# [323]	training's binary_logloss: 0.0173429	valid_1's binary_logloss: 0.0435178
# [324]	training's binary_logloss: 0.0172568	valid_1's binary_logloss: 0.0435706
# [325]	training's binary_logloss: 0.017174	valid_1's binary_logloss: 0.04352
# [326]	training's binary_logloss: 0.0171027	valid_1's binary_logloss: 0.0433833
# [327]	training's binary_logloss: 0.0169994	valid_1's binary_logloss: 0.0433019
# [328]	training's binary_logloss: 0.0168856	valid_1's binary_logloss: 0.0432652
# [329]	training's binary_logloss: 0.0167938	valid_1's binary_logloss: 0.0432295
# [330]	training's binary_logloss: 0.0166776	valid_1's binary_logloss: 0.0432224
# [331]	training's binary_logloss: 0.0165689	valid_1's binary_logloss: 0.0432871
# [332]	training's binary_logloss: 0.0164856	valid_1's binary_logloss: 0.0431571
# [333]	training's binary_logloss: 0.0163669	valid_1's binary_logloss: 0.0430443
# [334]	training's binary_logloss: 0.0162795	valid_1's binary_logloss: 0.042963
# [335]	training's binary_logloss: 0.0161954	valid_1's binary_logloss: 0.0428193
# [336]	training's binary_logloss: 0.0160129	valid_1's binary_logloss: 0.0424362
# [337]	training's binary_logloss: 0.0159393	valid_1's binary_logloss: 0.0423306
# [338]	training's binary_logloss: 0.0158541	valid_1's binary_logloss: 0.0423261
# [339]	training's binary_logloss: 0.015727	valid_1's binary_logloss: 0.0422295
# [340]	training's binary_logloss: 0.0156128	valid_1's binary_logloss: 0.0421784
# [341]	training's binary_logloss: 0.0155425	valid_1's binary_logloss: 0.0421088
# [342]	training's binary_logloss: 0.0154715	valid_1's binary_logloss: 0.0420006
# [343]	training's binary_logloss: 0.0154089	valid_1's binary_logloss: 0.0420064
# [344]	training's binary_logloss: 0.0152947	valid_1's binary_logloss: 0.0419405
# [345]	training's binary_logloss: 0.0151913	valid_1's binary_logloss: 0.0418426
# [346]	training's binary_logloss: 0.0150938	valid_1's binary_logloss: 0.041745
# [347]	training's binary_logloss: 0.0150243	valid_1's binary_logloss: 0.0416378
# [348]	training's binary_logloss: 0.0149288	valid_1's binary_logloss: 0.0415951
# [349]	training's binary_logloss: 0.0148223	valid_1's binary_logloss: 0.0414233
# [350]	training's binary_logloss: 0.0147681	valid_1's binary_logloss: 0.041354
# [351]	training's binary_logloss: 0.0146883	valid_1's binary_logloss: 0.0412588
# [352]	training's binary_logloss: 0.0146023	valid_1's binary_logloss: 0.0412558
# [353]	training's binary_logloss: 0.0145253	valid_1's binary_logloss: 0.0413035
# [354]	training's binary_logloss: 0.0144503	valid_1's binary_logloss: 0.0412539
# [355]	training's binary_logloss: 0.0143396	valid_1's binary_logloss: 0.0411927
# [356]	training's binary_logloss: 0.0142392	valid_1's binary_logloss: 0.0410171
# [357]	training's binary_logloss: 0.0141655	valid_1's binary_logloss: 0.0409098
# [358]	training's binary_logloss: 0.0140906	valid_1's binary_logloss: 0.0407818
# [359]	training's binary_logloss: 0.0139805	valid_1's binary_logloss: 0.0406595
# [360]	training's binary_logloss: 0.0139187	valid_1's binary_logloss: 0.0407212
# [361]	training's binary_logloss: 0.0138373	valid_1's binary_logloss: 0.0406323
# [362]	training's binary_logloss: 0.013741	valid_1's binary_logloss: 0.0404518
# [363]	training's binary_logloss: 0.013651	valid_1's binary_logloss: 0.0403347
# [364]	training's binary_logloss: 0.0135524	valid_1's binary_logloss: 0.0401171
# [365]	training's binary_logloss: 0.0134826	valid_1's binary_logloss: 0.0400282
# [366]	training's binary_logloss: 0.013361	valid_1's binary_logloss: 0.0399907
# [367]	training's binary_logloss: 0.0133131	valid_1's binary_logloss: 0.0399711
# [368]	training's binary_logloss: 0.0132259	valid_1's binary_logloss: 0.0397464
# [369]	training's binary_logloss: 0.0131481	valid_1's binary_logloss: 0.039694
# [370]	training's binary_logloss: 0.0130671	valid_1's binary_logloss: 0.0396661
# [371]	training's binary_logloss: 0.0129993	valid_1's binary_logloss: 0.0395592
# [372]	training's binary_logloss: 0.0129223	valid_1's binary_logloss: 0.0396339
# [373]	training's binary_logloss: 0.0128603	valid_1's binary_logloss: 0.0395101
# [374]	training's binary_logloss: 0.0128078	valid_1's binary_logloss: 0.0393989
# [375]	training's binary_logloss: 0.0126025	valid_1's binary_logloss: 0.0390784
# [376]	training's binary_logloss: 0.0125238	valid_1's binary_logloss: 0.0389892
# [377]	training's binary_logloss: 0.0124591	valid_1's binary_logloss: 0.038972
# [378]	training's binary_logloss: 0.0123461	valid_1's binary_logloss: 0.0387941
# [379]	training's binary_logloss: 0.0122903	valid_1's binary_logloss: 0.0387259
# [380]	training's binary_logloss: 0.0121937	valid_1's binary_logloss: 0.0386889
# [381]	training's binary_logloss: 0.0121173	valid_1's binary_logloss: 0.038617
# [382]	training's binary_logloss: 0.012026	valid_1's binary_logloss: 0.0385803
# [383]	training's binary_logloss: 0.0119828	valid_1's binary_logloss: 0.0385272
# [384]	training's binary_logloss: 0.0119196	valid_1's binary_logloss: 0.0385794
# [385]	training's binary_logloss: 0.0118556	valid_1's binary_logloss: 0.0383839
# [386]	training's binary_logloss: 0.0117886	valid_1's binary_logloss: 0.0382497
# [387]	training's binary_logloss: 0.011694	valid_1's binary_logloss: 0.038193
# [388]	training's binary_logloss: 0.0115998	valid_1's binary_logloss: 0.0380636
# [389]	training's binary_logloss: 0.0115469	valid_1's binary_logloss: 0.0380784
# [390]	training's binary_logloss: 0.011496	valid_1's binary_logloss: 0.0380546
# [391]	training's binary_logloss: 0.0114233	valid_1's binary_logloss: 0.0378438
# [392]	training's binary_logloss: 0.0113596	valid_1's binary_logloss: 0.0378986
# [393]	training's binary_logloss: 0.0112986	valid_1's binary_logloss: 0.0378317
# [394]	training's binary_logloss: 0.0112402	valid_1's binary_logloss: 0.0377831
# [395]	training's binary_logloss: 0.0111766	valid_1's binary_logloss: 0.0376744
# [396]	training's binary_logloss: 0.011132	valid_1's binary_logloss: 0.0375861
# [397]	training's binary_logloss: 0.0110791	valid_1's binary_logloss: 0.0375486
# [398]	training's binary_logloss: 0.0110071	valid_1's binary_logloss: 0.0374471
# [399]	training's binary_logloss: 0.0109549	valid_1's binary_logloss: 0.0373528
# [400]	training's binary_logloss: 0.0108934	valid_1's binary_logloss: 0.0373077
# [401]	training's binary_logloss: 0.0108549	valid_1's binary_logloss: 0.0372592
# [402]	training's binary_logloss: 0.0107281	valid_1's binary_logloss: 0.0368748
# [403]	training's binary_logloss: 0.0106706	valid_1's binary_logloss: 0.0368621
# [404]	training's binary_logloss: 0.0106048	valid_1's binary_logloss: 0.0367881
# [405]	training's binary_logloss: 0.010525	valid_1's binary_logloss: 0.0366505
# [406]	training's binary_logloss: 0.0104792	valid_1's binary_logloss: 0.0367005
# [407]	training's binary_logloss: 0.0104101	valid_1's binary_logloss: 0.0366117
# [408]	training's binary_logloss: 0.010365	valid_1's binary_logloss: 0.03663
# [409]	training's binary_logloss: 0.0102924	valid_1's binary_logloss: 0.0365508
# [410]	training's binary_logloss: 0.0102367	valid_1's binary_logloss: 0.0365307
# [411]	training's binary_logloss: 0.0101921	valid_1's binary_logloss: 0.0364562
# [412]	training's binary_logloss: 0.010138	valid_1's binary_logloss: 0.0364114
# [413]	training's binary_logloss: 0.0100753	valid_1's binary_logloss: 0.0364154
# [414]	training's binary_logloss: 0.0100155	valid_1's binary_logloss: 0.0363918
# [415]	training's binary_logloss: 0.0099588	valid_1's binary_logloss: 0.0363908
# [416]	training's binary_logloss: 0.00991667	valid_1's binary_logloss: 0.0363551
# [417]	training's binary_logloss: 0.00983949	valid_1's binary_logloss: 0.0362517
# [418]	training's binary_logloss: 0.00978761	valid_1's binary_logloss: 0.0362582
# [419]	training's binary_logloss: 0.00974562	valid_1's binary_logloss: 0.0362447
# [420]	training's binary_logloss: 0.00970019	valid_1's binary_logloss: 0.0362182
# [421]	training's binary_logloss: 0.00966483	valid_1's binary_logloss: 0.0361763
# [422]	training's binary_logloss: 0.00962618	valid_1's binary_logloss: 0.0361117
# [423]	training's binary_logloss: 0.00958189	valid_1's binary_logloss: 0.0360988
# [424]	training's binary_logloss: 0.00952223	valid_1's binary_logloss: 0.0359611
# [425]	training's binary_logloss: 0.00943577	valid_1's binary_logloss: 0.0358213
# [426]	training's binary_logloss: 0.00939967	valid_1's binary_logloss: 0.0357464
# [427]	training's binary_logloss: 0.00933552	valid_1's binary_logloss: 0.0357093
# [428]	training's binary_logloss: 0.00929524	valid_1's binary_logloss: 0.0356315
# [429]	training's binary_logloss: 0.00924875	valid_1's binary_logloss: 0.0356088
# [430]	training's binary_logloss: 0.00919579	valid_1's binary_logloss: 0.0356143
# [431]	training's binary_logloss: 0.00914386	valid_1's binary_logloss: 0.0355881
# [432]	training's binary_logloss: 0.00906311	valid_1's binary_logloss: 0.0355016
# [433]	training's binary_logloss: 0.00900933	valid_1's binary_logloss: 0.0355641
# [434]	training's binary_logloss: 0.00895565	valid_1's binary_logloss: 0.0354639
# [435]	training's binary_logloss: 0.00886719	valid_1's binary_logloss: 0.0353093
# [436]	training's binary_logloss: 0.00880289	valid_1's binary_logloss: 0.035161
# [437]	training's binary_logloss: 0.00875303	valid_1's binary_logloss: 0.0351396
# [438]	training's binary_logloss: 0.00870947	valid_1's binary_logloss: 0.035123
# [439]	training's binary_logloss: 0.00866134	valid_1's binary_logloss: 0.034998
# [440]	training's binary_logloss: 0.00858414	valid_1's binary_logloss: 0.0349112
# [441]	training's binary_logloss: 0.00848534	valid_1's binary_logloss: 0.0346697
# [442]	training's binary_logloss: 0.00844484	valid_1's binary_logloss: 0.0346445
# [443]	training's binary_logloss: 0.00840576	valid_1's binary_logloss: 0.0346081
# [444]	training's binary_logloss: 0.00834173	valid_1's binary_logloss: 0.0346282
# [445]	training's binary_logloss: 0.00829015	valid_1's binary_logloss: 0.0345048
# [446]	training's binary_logloss: 0.00824572	valid_1's binary_logloss: 0.0345626
# [447]	training's binary_logloss: 0.00820106	valid_1's binary_logloss: 0.0345589
# [448]	training's binary_logloss: 0.00816217	valid_1's binary_logloss: 0.0345591
# [449]	training's binary_logloss: 0.00813207	valid_1's binary_logloss: 0.034525
# [450]	training's binary_logloss: 0.00810242	valid_1's binary_logloss: 0.0345089
# [451]	training's binary_logloss: 0.00806197	valid_1's binary_logloss: 0.0344506
# [452]	training's binary_logloss: 0.00801545	valid_1's binary_logloss: 0.0344452
# [453]	training's binary_logloss: 0.00795768	valid_1's binary_logloss: 0.0344449
# [454]	training's binary_logloss: 0.0078978	valid_1's binary_logloss: 0.0343948
# [455]	training's binary_logloss: 0.00786253	valid_1's binary_logloss: 0.0343281
# [456]	training's binary_logloss: 0.0078289	valid_1's binary_logloss: 0.0343034
# [457]	training's binary_logloss: 0.00779772	valid_1's binary_logloss: 0.0342699
# [458]	training's binary_logloss: 0.00775469	valid_1's binary_logloss: 0.0342628
# [459]	training's binary_logloss: 0.0077286	valid_1's binary_logloss: 0.0342031
# [460]	training's binary_logloss: 0.00769662	valid_1's binary_logloss: 0.0341552
# [461]	training's binary_logloss: 0.00764656	valid_1's binary_logloss: 0.0341245
# [462]	training's binary_logloss: 0.00759482	valid_1's binary_logloss: 0.0341904
# [463]	training's binary_logloss: 0.00754047	valid_1's binary_logloss: 0.0340708
# [464]	training's binary_logloss: 0.00747847	valid_1's binary_logloss: 0.0340072
# [465]	training's binary_logloss: 0.0074355	valid_1's binary_logloss: 0.0339298
# [466]	training's binary_logloss: 0.00738326	valid_1's binary_logloss: 0.0338632
# [467]	training's binary_logloss: 0.00732313	valid_1's binary_logloss: 0.0338418
# [468]	training's binary_logloss: 0.00727886	valid_1's binary_logloss: 0.0337776
# [469]	training's binary_logloss: 0.00724772	valid_1's binary_logloss: 0.0338248
# [470]	training's binary_logloss: 0.00721144	valid_1's binary_logloss: 0.0337963
# [471]	training's binary_logloss: 0.0071781	valid_1's binary_logloss: 0.0337411
# [472]	training's binary_logloss: 0.00712611	valid_1's binary_logloss: 0.0336625
# [473]	training's binary_logloss: 0.00708441	valid_1's binary_logloss: 0.033703
# [474]	training's binary_logloss: 0.00704384	valid_1's binary_logloss: 0.0335879
# [475]	training's binary_logloss: 0.00699845	valid_1's binary_logloss: 0.0335481
# [476]	training's binary_logloss: 0.00697812	valid_1's binary_logloss: 0.0335801
# [477]	training's binary_logloss: 0.00693966	valid_1's binary_logloss: 0.0335502
# [478]	training's binary_logloss: 0.00691201	valid_1's binary_logloss: 0.0334743
# [479]	training's binary_logloss: 0.00687875	valid_1's binary_logloss: 0.0334128
# [480]	training's binary_logloss: 0.0068391	valid_1's binary_logloss: 0.033478
# [481]	training's binary_logloss: 0.00678702	valid_1's binary_logloss: 0.0332914
# [482]	training's binary_logloss: 0.00671687	valid_1's binary_logloss: 0.0330265
# [483]	training's binary_logloss: 0.0066859	valid_1's binary_logloss: 0.0330418
# [484]	training's binary_logloss: 0.00664875	valid_1's binary_logloss: 0.0329525
# [485]	training's binary_logloss: 0.00662068	valid_1's binary_logloss: 0.0329122
# [486]	training's binary_logloss: 0.00656704	valid_1's binary_logloss: 0.0328397
# [487]	training's binary_logloss: 0.00653333	valid_1's binary_logloss: 0.0328134
# [488]	training's binary_logloss: 0.0064865	valid_1's binary_logloss: 0.0328168
# [489]	training's binary_logloss: 0.00644909	valid_1's binary_logloss: 0.0326879
# [490]	training's binary_logloss: 0.00640014	valid_1's binary_logloss: 0.032694
# [491]	training's binary_logloss: 0.00637486	valid_1's binary_logloss: 0.0327234
# [492]	training's binary_logloss: 0.00633402	valid_1's binary_logloss: 0.0326652
# [493]	training's binary_logloss: 0.00630099	valid_1's binary_logloss: 0.0326411
# [494]	training's binary_logloss: 0.00627704	valid_1's binary_logloss: 0.0325813
# [495]	training's binary_logloss: 0.00624204	valid_1's binary_logloss: 0.0325083
# [496]	training's binary_logloss: 0.00620702	valid_1's binary_logloss: 0.0324735
# [497]	training's binary_logloss: 0.00617112	valid_1's binary_logloss: 0.0324382
# [498]	training's binary_logloss: 0.00612206	valid_1's binary_logloss: 0.0324397
# [499]	training's binary_logloss: 0.00607447	valid_1's binary_logloss: 0.0322819
# [500]	training's binary_logloss: 0.00604596	valid_1's binary_logloss: 0.0322576
# [501]	training's binary_logloss: 0.00602303	valid_1's binary_logloss: 0.0322093
# [502]	training's binary_logloss: 0.00600135	valid_1's binary_logloss: 0.0322019
# [503]	training's binary_logloss: 0.00596879	valid_1's binary_logloss: 0.0321268
# [504]	training's binary_logloss: 0.00594111	valid_1's binary_logloss: 0.0319828
# [505]	training's binary_logloss: 0.00590476	valid_1's binary_logloss: 0.0318892
# [506]	training's binary_logloss: 0.00586096	valid_1's binary_logloss: 0.0318814
# [507]	training's binary_logloss: 0.00583764	valid_1's binary_logloss: 0.0319158
# [508]	training's binary_logloss: 0.00580809	valid_1's binary_logloss: 0.0318887
# [509]	training's binary_logloss: 0.00576697	valid_1's binary_logloss: 0.031871
# [510]	training's binary_logloss: 0.00573414	valid_1's binary_logloss: 0.0318471
# [511]	training's binary_logloss: 0.00570554	valid_1's binary_logloss: 0.0318098
# [512]	training's binary_logloss: 0.00567201	valid_1's binary_logloss: 0.031839
# [513]	training's binary_logloss: 0.00563812	valid_1's binary_logloss: 0.0318303
# [514]	training's binary_logloss: 0.00560457	valid_1's binary_logloss: 0.0317265
# [515]	training's binary_logloss: 0.0055656	valid_1's binary_logloss: 0.0317045
# [516]	training's binary_logloss: 0.00554118	valid_1's binary_logloss: 0.0316893
# [517]	training's binary_logloss: 0.00552227	valid_1's binary_logloss: 0.0316835
# [518]	training's binary_logloss: 0.00549114	valid_1's binary_logloss: 0.0316503
# [519]	training's binary_logloss: 0.00541279	valid_1's binary_logloss: 0.0315055
# [520]	training's binary_logloss: 0.00538389	valid_1's binary_logloss: 0.0314908
# [521]	training's binary_logloss: 0.00535571	valid_1's binary_logloss: 0.0314653
# [522]	training's binary_logloss: 0.00532933	valid_1's binary_logloss: 0.0314932
# [523]	training's binary_logloss: 0.00530443	valid_1's binary_logloss: 0.0315169
# [524]	training's binary_logloss: 0.00527178	valid_1's binary_logloss: 0.0315431
# [525]	training's binary_logloss: 0.00524572	valid_1's binary_logloss: 0.0315252
# [526]	training's binary_logloss: 0.00522243	valid_1's binary_logloss: 0.0315126
# [527]	training's binary_logloss: 0.00520002	valid_1's binary_logloss: 0.0315337
# [528]	training's binary_logloss: 0.00518136	valid_1's binary_logloss: 0.0314972
# [529]	training's binary_logloss: 0.00516381	valid_1's binary_logloss: 0.0315386
# [530]	training's binary_logloss: 0.00514283	valid_1's binary_logloss: 0.0315327
# [531]	training's binary_logloss: 0.0051102	valid_1's binary_logloss: 0.0314769
# [532]	training's binary_logloss: 0.00508102	valid_1's binary_logloss: 0.031341
# [533]	training's binary_logloss: 0.00505758	valid_1's binary_logloss: 0.031354
# [534]	training's binary_logloss: 0.00504152	valid_1's binary_logloss: 0.03136
# [535]	training's binary_logloss: 0.00501843	valid_1's binary_logloss: 0.0313507
# [536]	training's binary_logloss: 0.0049929	valid_1's binary_logloss: 0.0312864
# [537]	training's binary_logloss: 0.00496752	valid_1's binary_logloss: 0.0312878
# [538]	training's binary_logloss: 0.00492521	valid_1's binary_logloss: 0.0312255
# [539]	training's binary_logloss: 0.00489423	valid_1's binary_logloss: 0.0311753
# [540]	training's binary_logloss: 0.00487121	valid_1's binary_logloss: 0.0311844
# [541]	training's binary_logloss: 0.00483822	valid_1's binary_logloss: 0.0312084
# [542]	training's binary_logloss: 0.00481219	valid_1's binary_logloss: 0.0312039
# [543]	training's binary_logloss: 0.00478453	valid_1's binary_logloss: 0.0311701
# [544]	training's binary_logloss: 0.00474828	valid_1's binary_logloss: 0.0311651
# [545]	training's binary_logloss: 0.00472138	valid_1's binary_logloss: 0.0310617
# [546]	training's binary_logloss: 0.00469359	valid_1's binary_logloss: 0.0311211
# [547]	training's binary_logloss: 0.00465817	valid_1's binary_logloss: 0.0310542
# [548]	training's binary_logloss: 0.00463864	valid_1's binary_logloss: 0.0311019
# [549]	training's binary_logloss: 0.00461533	valid_1's binary_logloss: 0.0310933
# [550]	training's binary_logloss: 0.00459499	valid_1's binary_logloss: 0.0311027
# [551]	training's binary_logloss: 0.00456364	valid_1's binary_logloss: 0.0310689
# [552]	training's binary_logloss: 0.00453623	valid_1's binary_logloss: 0.0310943
# [553]	training's binary_logloss: 0.00451212	valid_1's binary_logloss: 0.0310638
# [554]	training's binary_logloss: 0.004491	valid_1's binary_logloss: 0.0310752
# [555]	training's binary_logloss: 0.00447141	valid_1's binary_logloss: 0.0310945
# [556]	training's binary_logloss: 0.00445307	valid_1's binary_logloss: 0.0310793
# [557]	training's binary_logloss: 0.0044298	valid_1's binary_logloss: 0.0310665
# [558]	training's binary_logloss: 0.0044109	valid_1's binary_logloss: 0.0309651
# [559]	training's binary_logloss: 0.00438766	valid_1's binary_logloss: 0.0309912
# [560]	training's binary_logloss: 0.004363	valid_1's binary_logloss: 0.0309556
# [561]	training's binary_logloss: 0.00434507	valid_1's binary_logloss: 0.0308631
# [562]	training's binary_logloss: 0.00432085	valid_1's binary_logloss: 0.0308767
# [563]	training's binary_logloss: 0.00429785	valid_1's binary_logloss: 0.0307998
# [564]	training's binary_logloss: 0.00427654	valid_1's binary_logloss: 0.0307773
# [565]	training's binary_logloss: 0.00425763	valid_1's binary_logloss: 0.0307247
# [566]	training's binary_logloss: 0.00424108	valid_1's binary_logloss: 0.0307079
# [567]	training's binary_logloss: 0.00421794	valid_1's binary_logloss: 0.0307095
# [568]	training's binary_logloss: 0.00419853	valid_1's binary_logloss: 0.030692
# [569]	training's binary_logloss: 0.00416813	valid_1's binary_logloss: 0.0307167
# [570]	training's binary_logloss: 0.00413904	valid_1's binary_logloss: 0.0306575
# [571]	training's binary_logloss: 0.00411971	valid_1's binary_logloss: 0.0306647
# [572]	training's binary_logloss: 0.00410403	valid_1's binary_logloss: 0.0306328
# [573]	training's binary_logloss: 0.00407585	valid_1's binary_logloss: 0.0305855
# [574]	training's binary_logloss: 0.00405764	valid_1's binary_logloss: 0.0305022
# [575]	training's binary_logloss: 0.00403412	valid_1's binary_logloss: 0.0305154
# [576]	training's binary_logloss: 0.00401176	valid_1's binary_logloss: 0.0305317
# [577]	training's binary_logloss: 0.00399667	valid_1's binary_logloss: 0.0304868
# [578]	training's binary_logloss: 0.00397077	valid_1's binary_logloss: 0.0304385
# [579]	training's binary_logloss: 0.00395534	valid_1's binary_logloss: 0.0303836
# [580]	training's binary_logloss: 0.0039365	valid_1's binary_logloss: 0.0303763
# [581]	training's binary_logloss: 0.00391907	valid_1's binary_logloss: 0.0303424
# [582]	training's binary_logloss: 0.0039049	valid_1's binary_logloss: 0.0302946
# [583]	training's binary_logloss: 0.00388735	valid_1's binary_logloss: 0.0302251
# [584]	training's binary_logloss: 0.00386647	valid_1's binary_logloss: 0.0301827
# [585]	training's binary_logloss: 0.0038435	valid_1's binary_logloss: 0.0301205
# [586]	training's binary_logloss: 0.00382302	valid_1's binary_logloss: 0.0300706
# [587]	training's binary_logloss: 0.00380662	valid_1's binary_logloss: 0.0300497
# [588]	training's binary_logloss: 0.00378932	valid_1's binary_logloss: 0.0300297
# [589]	training's binary_logloss: 0.00375608	valid_1's binary_logloss: 0.0299941
# [590]	training's binary_logloss: 0.00372157	valid_1's binary_logloss: 0.0299964
# [591]	training's binary_logloss: 0.00369532	valid_1's binary_logloss: 0.0300101
# [592]	training's binary_logloss: 0.00366764	valid_1's binary_logloss: 0.0299848
# [593]	training's binary_logloss: 0.00359884	valid_1's binary_logloss: 0.0296826
# [594]	training's binary_logloss: 0.00358268	valid_1's binary_logloss: 0.0296859
# [595]	training's binary_logloss: 0.00357007	valid_1's binary_logloss: 0.0296732
# [596]	training's binary_logloss: 0.00355375	valid_1's binary_logloss: 0.0296934
# [597]	training's binary_logloss: 0.0035305	valid_1's binary_logloss: 0.0297278
# [598]	training's binary_logloss: 0.0035068	valid_1's binary_logloss: 0.0297158
# [599]	training's binary_logloss: 0.00347354	valid_1's binary_logloss: 0.0295599
# [600]	training's binary_logloss: 0.00345226	valid_1's binary_logloss: 0.0294287
# [601]	training's binary_logloss: 0.00343429	valid_1's binary_logloss: 0.0293322
# [602]	training's binary_logloss: 0.00341041	valid_1's binary_logloss: 0.0293494
# [603]	training's binary_logloss: 0.00337968	valid_1's binary_logloss: 0.0292708
# [604]	training's binary_logloss: 0.00336609	valid_1's binary_logloss: 0.0292668
# [605]	training's binary_logloss: 0.00332533	valid_1's binary_logloss: 0.0290101
# [606]	training's binary_logloss: 0.0033008	valid_1's binary_logloss: 0.0290357
# [607]	training's binary_logloss: 0.00328879	valid_1's binary_logloss: 0.029004
# [608]	training's binary_logloss: 0.00327497	valid_1's binary_logloss: 0.0289691
# [609]	training's binary_logloss: 0.00325557	valid_1's binary_logloss: 0.0289707
# ...
# [1283]	training's binary_logloss: 8.19178e-05	valid_1's binary_logloss: 0.025527
# [1284]	training's binary_logloss: 8.14595e-05	valid_1's binary_logloss: 0.0255203
# [1285]	training's binary_logloss: 8.10659e-05	valid_1's binary_logloss: 0.0255003
# [1286]	training's binary_logloss: 8.07035e-05	valid_1's binary_logloss: 0.0255031
# [1287]	training's binary_logloss: 8.0477e-05	valid_1's binary_logloss: 0.0255388
# [1288]	training's binary_logloss: 7.99534e-05	valid_1's binary_logloss: 0.0256113
# [1289]	training's binary_logloss: 7.96726e-05	valid_1's binary_logloss: 0.0255615
# [1290]	training's binary_logloss: 7.92007e-05	valid_1's binary_logloss: 0.0254685
# [1291]	training's binary_logloss: 7.88674e-05	valid_1's binary_logloss: 0.0254837
# [1292]	training's binary_logloss: 7.86299e-05	valid_1's binary_logloss: 0.0254771
# [1293]	training's binary_logloss: 7.82589e-05	valid_1's binary_logloss: 0.0255033
# [1294]	training's binary_logloss: 7.78794e-05	valid_1's binary_logloss: 0.0255114
# [1295]	training's binary_logloss: 7.74919e-05	valid_1's binary_logloss: 0.0254718
# [1296]	training's binary_logloss: 7.71045e-05	valid_1's binary_logloss: 0.025457
# [1297]	training's binary_logloss: 7.67398e-05	valid_1's binary_logloss: 0.0254678
# [1298]	training's binary_logloss: 7.63542e-05	valid_1's binary_logloss: 0.0254739
# [1299]	training's binary_logloss: 7.59702e-05	valid_1's binary_logloss: 0.0254805
# [1300]	training's binary_logloss: 7.56949e-05	valid_1's binary_logloss: 0.025477
# [1301]	training's binary_logloss: 7.54767e-05	valid_1's binary_logloss: 0.0255478
# [1302]	training's binary_logloss: 7.51615e-05	valid_1's binary_logloss: 0.0255819
# [1303]	training's binary_logloss: 7.49425e-05	valid_1's binary_logloss: 0.0255751
# [1304]	training's binary_logloss: 7.43922e-05	valid_1's binary_logloss: 0.0256168
# [1305]	training's binary_logloss: 7.3953e-05	valid_1's binary_logloss: 0.0256672
# [1306]	training's binary_logloss: 7.35282e-05	valid_1's binary_logloss: 0.0256813
# [1307]	training's binary_logloss: 7.30457e-05	valid_1's binary_logloss: 0.0257153
# [1308]	training's binary_logloss: 7.27251e-05	valid_1's binary_logloss: 0.0258001
# [1309]	training's binary_logloss: 7.23495e-05	valid_1's binary_logloss: 0.0257577
# [1310]	training's binary_logloss: 7.2034e-05	valid_1's binary_logloss: 0.0257236
# [1311]	training's binary_logloss: 7.14035e-05	valid_1's binary_logloss: 0.0256974
# [1312]	training's binary_logloss: 7.08563e-05	valid_1's binary_logloss: 0.0257879
# [1313]	training's binary_logloss: 7.0508e-05	valid_1's binary_logloss: 0.0257571
# [1314]	training's binary_logloss: 7.0225e-05	valid_1's binary_logloss: 0.0257533
# [1315]	training's binary_logloss: 6.99989e-05	valid_1's binary_logloss: 0.0257349
# [1316]	training's binary_logloss: 6.95635e-05	valid_1's binary_logloss: 0.0256899
# [1317]	training's binary_logloss: 6.93519e-05	valid_1's binary_logloss: 0.0256102
# [1318]	training's binary_logloss: 6.90675e-05	valid_1's binary_logloss: 0.0256763
# [1319]	training's binary_logloss: 6.86281e-05	valid_1's binary_logloss: 0.0257092
# [1320]	training's binary_logloss: 6.83897e-05	valid_1's binary_logloss: 0.02573
# [1321]	training's binary_logloss: 6.8031e-05	valid_1's binary_logloss: 0.0257854
# [1322]	training's binary_logloss: 6.76217e-05	valid_1's binary_logloss: 0.0258079
# [1323]	training's binary_logloss: 6.71639e-05	valid_1's binary_logloss: 0.0258711
# [1324]	training's binary_logloss: 6.68835e-05	valid_1's binary_logloss: 0.0259025
# [1325]	training's binary_logloss: 6.63568e-05	valid_1's binary_logloss: 0.0258959
# [1326]	training's binary_logloss: 6.60995e-05	valid_1's binary_logloss: 0.0259146
# [1327]	training's binary_logloss: 6.55639e-05	valid_1's binary_logloss: 0.0258731
# [1328]	training's binary_logloss: 6.52786e-05	valid_1's binary_logloss: 0.0258944
# [1329]	training's binary_logloss: 6.47714e-05	valid_1's binary_logloss: 0.0258935
# [1330]	training's binary_logloss: 6.453e-05	valid_1's binary_logloss: 0.0258908
# [1331]	training's binary_logloss: 6.41875e-05	valid_1's binary_logloss: 0.025916
# [1332]	training's binary_logloss: 6.38953e-05	valid_1's binary_logloss: 0.0258955
# [1333]	training's binary_logloss: 6.35115e-05	valid_1's binary_logloss: 0.0258672
# [1334]	training's binary_logloss: 6.33095e-05	valid_1's binary_logloss: 0.025875
# [1335]	training's binary_logloss: 6.30686e-05	valid_1's binary_logloss: 0.0259028
# [1336]	training's binary_logloss: 6.28582e-05	valid_1's binary_logloss: 0.0259505
# [1337]	training's binary_logloss: 6.26136e-05	valid_1's binary_logloss: 0.0259685
# [1338]	training's binary_logloss: 6.23024e-05	valid_1's binary_logloss: 0.025997
# [1339]	training's binary_logloss: 6.21249e-05	valid_1's binary_logloss: 0.0259971
# [1340]	training's binary_logloss: 6.18047e-05	valid_1's binary_logloss: 0.026011
# [1341]	training's binary_logloss: 6.15999e-05	valid_1's binary_logloss: 0.02603
# [1342]	training's binary_logloss: 6.12723e-05	valid_1's binary_logloss: 0.0260445
# [1343]	training's binary_logloss: 6.09057e-05	valid_1's binary_logloss: 0.0260127
# [1344]	training's binary_logloss: 6.05897e-05	valid_1's binary_logloss: 0.0260298
# [1345]	training's binary_logloss: 6.02631e-05	valid_1's binary_logloss: 0.0260255
# [1346]	training's binary_logloss: 6.0044e-05	valid_1's binary_logloss: 0.0260228
# [1347]	training's binary_logloss: 5.97715e-05	valid_1's binary_logloss: 0.0259763
# [1348]	training's binary_logloss: 5.94936e-05	valid_1's binary_logloss: 0.0259692
# [1349]	training's binary_logloss: 5.91546e-05	valid_1's binary_logloss: 0.0259156
# [1350]	training's binary_logloss: 5.88817e-05	valid_1's binary_logloss: 0.0259668
# [1351]	training's binary_logloss: 5.84962e-05	valid_1's binary_logloss: 0.0259897
# [1352]	training's binary_logloss: 5.81528e-05	valid_1's binary_logloss: 0.0259805
# [1353]	training's binary_logloss: 5.79259e-05	valid_1's binary_logloss: 0.0261047
# [1354]	training's binary_logloss: 5.76194e-05	valid_1's binary_logloss: 0.0261313
# [1355]	training's binary_logloss: 5.72937e-05	valid_1's binary_logloss: 0.0261385
# [1356]	training's binary_logloss: 5.70019e-05	valid_1's binary_logloss: 0.0261512
# [1357]	training's binary_logloss: 5.68424e-05	valid_1's binary_logloss: 0.0261522
# [1358]	training's binary_logloss: 5.64787e-05	valid_1's binary_logloss: 0.0261322
# [1359]	training's binary_logloss: 5.6232e-05	valid_1's binary_logloss: 0.026088
# [1360]	training's binary_logloss: 5.60369e-05	valid_1's binary_logloss: 0.0260528
# [1361]	training's binary_logloss: 5.57218e-05	valid_1's binary_logloss: 0.0260469
# [1362]	training's binary_logloss: 5.54155e-05	valid_1's binary_logloss: 0.026053
# [1363]	training's binary_logloss: 5.50776e-05	valid_1's binary_logloss: 0.0260845
# [1364]	training's binary_logloss: 5.49216e-05	valid_1's binary_logloss: 0.0260814
# [1365]	training's binary_logloss: 5.45332e-05	valid_1's binary_logloss: 0.0259838
# [1366]	training's binary_logloss: 5.42231e-05	valid_1's binary_logloss: 0.0259759
# [1367]	training's binary_logloss: 5.39674e-05	valid_1's binary_logloss: 0.0259305
# [1368]	training's binary_logloss: 5.37642e-05	valid_1's binary_logloss: 0.0259497
# [1369]	training's binary_logloss: 5.35009e-05	valid_1's binary_logloss: 0.0260633
# [1370]	training's binary_logloss: 5.32934e-05	valid_1's binary_logloss: 0.02607
# [1371]	training's binary_logloss: 5.29451e-05	valid_1's binary_logloss: 0.0261553
# [1372]	training's binary_logloss: 5.26998e-05	valid_1's binary_logloss: 0.0261871
# [1373]	training's binary_logloss: 5.24328e-05	valid_1's binary_logloss: 0.0262342
# [1374]	training's binary_logloss: 5.22857e-05	valid_1's binary_logloss: 0.0262366
# [1375]	training's binary_logloss: 5.19334e-05	valid_1's binary_logloss: 0.0262878
# [1376]	training's binary_logloss: 5.16258e-05	valid_1's binary_logloss: 0.0262583
# [1377]	training's binary_logloss: 5.07986e-05	valid_1's binary_logloss: 0.0261327
# [1378]	training's binary_logloss: 5.05235e-05	valid_1's binary_logloss: 0.0261061
# [1379]	training's binary_logloss: 5.00724e-05	valid_1's binary_logloss: 0.0260931
# [1380]	training's binary_logloss: 4.98899e-05	valid_1's binary_logloss: 0.0260895
# [1381]	training's binary_logloss: 4.96524e-05	valid_1's binary_logloss: 0.0260668
# [1382]	training's binary_logloss: 4.93445e-05	valid_1's binary_logloss: 0.0260982
# [1383]	training's binary_logloss: 4.91651e-05	valid_1's binary_logloss: 0.0260315
# [1384]	training's binary_logloss: 4.89545e-05	valid_1's binary_logloss: 0.0260879
# [1385]	training's binary_logloss: 4.87849e-05	valid_1's binary_logloss: 0.0261077
# [1386]	training's binary_logloss: 4.84123e-05	valid_1's binary_logloss: 0.026225
# [1387]	training's binary_logloss: 4.82171e-05	valid_1's binary_logloss: 0.026198
# [1388]	training's binary_logloss: 4.80352e-05	valid_1's binary_logloss: 0.026235
# [1389]	training's binary_logloss: 4.77506e-05	valid_1's binary_logloss: 0.0262491
# [1390]	training's binary_logloss: 4.74568e-05	valid_1's binary_logloss: 0.0262608
# [1391]	training's binary_logloss: 4.72148e-05	valid_1's binary_logloss: 0.0262355
# [1392]	training's binary_logloss: 4.69366e-05	valid_1's binary_logloss: 0.0262891
# [1393]	training's binary_logloss: 4.67517e-05	valid_1's binary_logloss: 0.0262923
# [1394]	training's binary_logloss: 4.64471e-05	valid_1's binary_logloss: 0.0262764
# [1395]	training's binary_logloss: 4.6266e-05	valid_1's binary_logloss: 0.0262645
# [1396]	training's binary_logloss: 4.58783e-05	valid_1's binary_logloss: 0.026286
# [1397]	training's binary_logloss: 4.57637e-05	valid_1's binary_logloss: 0.0263034
# [1398]	training's binary_logloss: 4.56287e-05	valid_1's binary_logloss: 0.02633
# [1399]	training's binary_logloss: 4.53352e-05	valid_1's binary_logloss: 0.0263797
# [1400]	training's binary_logloss: 4.5122e-05	valid_1's binary_logloss: 0.0263651
# [1401]	training's binary_logloss: 4.48838e-05	valid_1's binary_logloss: 0.0263496
# [1402]	training's binary_logloss: 4.46152e-05	valid_1's binary_logloss: 0.0263787
# [1403]	training's binary_logloss: 4.44103e-05	valid_1's binary_logloss: 0.0263708
# [1404]	training's binary_logloss: 4.4284e-05	valid_1's binary_logloss: 0.0263765
# [1405]	training's binary_logloss: 4.41204e-05	valid_1's binary_logloss: 0.0263831
# [1406]	training's binary_logloss: 4.38122e-05	valid_1's binary_logloss: 0.0263792
# [1407]	training's binary_logloss: 4.35765e-05	valid_1's binary_logloss: 0.0263923
# [1408]	training's binary_logloss: 4.3361e-05	valid_1's binary_logloss: 0.0264111
# [1409]	training's binary_logloss: 4.30827e-05	valid_1's binary_logloss: 0.0263416
# [1410]	training's binary_logloss: 4.28588e-05	valid_1's binary_logloss: 0.0263591
# [1411]	training's binary_logloss: 4.26881e-05	valid_1's binary_logloss: 0.0263701
# [1412]	training's binary_logloss: 4.25235e-05	valid_1's binary_logloss: 0.0264128
# [1413]	training's binary_logloss: 4.23867e-05	valid_1's binary_logloss: 0.0264394
# [1414]	training's binary_logloss: 4.20421e-05	valid_1's binary_logloss: 0.0264731
# [1415]	training's binary_logloss: 4.18788e-05	valid_1's binary_logloss: 0.0264688
# [1416]	training's binary_logloss: 4.16046e-05	valid_1's binary_logloss: 0.0265299
# [1417]	training's binary_logloss: 4.1417e-05	valid_1's binary_logloss: 0.0264784
# [1418]	training's binary_logloss: 4.11937e-05	valid_1's binary_logloss: 0.0264919
# [1419]	training's binary_logloss: 4.09403e-05	valid_1's binary_logloss: 0.0265078
# [1420]	training's binary_logloss: 4.069e-05	valid_1's binary_logloss: 0.0265629
# [1421]	training's binary_logloss: 4.05173e-05	valid_1's binary_logloss: 0.0266437
# [1422]	training's binary_logloss: 4.02701e-05	valid_1's binary_logloss: 0.0266734
# [1423]	training's binary_logloss: 4.00135e-05	valid_1's binary_logloss: 0.0266982
# [1424]	training's binary_logloss: 3.98998e-05	valid_1's binary_logloss: 0.0266942
# [1425]	training's binary_logloss: 3.97301e-05	valid_1's binary_logloss: 0.0267903
# [1426]	training's binary_logloss: 3.95513e-05	valid_1's binary_logloss: 0.0267814
# [1427]	training's binary_logloss: 3.94061e-05	valid_1's binary_logloss: 0.0267768
# [1428]	training's binary_logloss: 3.92493e-05	valid_1's binary_logloss: 0.0267488
# [1429]	training's binary_logloss: 3.91431e-05	valid_1's binary_logloss: 0.0267
# [1430]	training's binary_logloss: 3.8955e-05	valid_1's binary_logloss: 0.0266631
# [1431]	training's binary_logloss: 3.86734e-05	valid_1's binary_logloss: 0.0266281
# [1432]	training's binary_logloss: 3.84727e-05	valid_1's binary_logloss: 0.026718
# [1433]	training's binary_logloss: 3.82292e-05	valid_1's binary_logloss: 0.0266941
# [1434]	training's binary_logloss: 3.79295e-05	valid_1's binary_logloss: 0.0266223
# [1435]	training's binary_logloss: 3.77028e-05	valid_1's binary_logloss: 0.0265884
# [1436]	training's binary_logloss: 3.74429e-05	valid_1's binary_logloss: 0.0264967
# [1437]	training's binary_logloss: 3.72466e-05	valid_1's binary_logloss: 0.0264866
# [1438]	training's binary_logloss: 3.70889e-05	valid_1's binary_logloss: 0.0264956
# [1439]	training's binary_logloss: 3.6888e-05	valid_1's binary_logloss: 0.0264773
# [1440]	training's binary_logloss: 3.67432e-05	valid_1's binary_logloss: 0.0265161
# [1441]	training's binary_logloss: 3.64797e-05	valid_1's binary_logloss: 0.026551
# [1442]	training's binary_logloss: 3.63322e-05	valid_1's binary_logloss: 0.0264876
# [1443]	training's binary_logloss: 3.6113e-05	valid_1's binary_logloss: 0.0264636
# [1444]	training's binary_logloss: 3.59098e-05	valid_1's binary_logloss: 0.0264315
# [1445]	training's binary_logloss: 3.57468e-05	valid_1's binary_logloss: 0.0264323
# [1446]	training's binary_logloss: 3.55696e-05	valid_1's binary_logloss: 0.0265376
# [1447]	training's binary_logloss: 3.5389e-05	valid_1's binary_logloss: 0.0265281
# [1448]	training's binary_logloss: 3.51204e-05	valid_1's binary_logloss: 0.0264875
# [1449]	training's binary_logloss: 3.49043e-05	valid_1's binary_logloss: 0.0264808
# [1450]	training's binary_logloss: 3.47117e-05	valid_1's binary_logloss: 0.0264993
# [1451]	training's binary_logloss: 3.44615e-05	valid_1's binary_logloss: 0.0264772
# [1452]	training's binary_logloss: 3.42534e-05	valid_1's binary_logloss: 0.0264561
# [1453]	training's binary_logloss: 3.41365e-05	valid_1's binary_logloss: 0.0264576
# [1454]	training's binary_logloss: 3.40283e-05	valid_1's binary_logloss: 0.0264238
# [1455]	training's binary_logloss: 3.35771e-05	valid_1's binary_logloss: 0.0263743
# [1456]	training's binary_logloss: 3.34089e-05	valid_1's binary_logloss: 0.0263421
# [1457]	training's binary_logloss: 3.29899e-05	valid_1's binary_logloss: 0.0262453
# [1458]	training's binary_logloss: 3.28208e-05	valid_1's binary_logloss: 0.0262708
# [1459]	training's binary_logloss: 3.26835e-05	valid_1's binary_logloss: 0.0262941
# [1460]	training's binary_logloss: 3.25812e-05	valid_1's binary_logloss: 0.0263438
# [1461]	training's binary_logloss: 3.24644e-05	valid_1's binary_logloss: 0.0262895
# [1462]	training's binary_logloss: 3.22453e-05	valid_1's binary_logloss: 0.0263001
# [1463]	training's binary_logloss: 3.20535e-05	valid_1's binary_logloss: 0.0263136
# [1464]	training's binary_logloss: 3.19258e-05	valid_1's binary_logloss: 0.0263719
# [1465]	training's binary_logloss: 3.1769e-05	valid_1's binary_logloss: 0.0264333
# [1466]	training's binary_logloss: 3.15221e-05	valid_1's binary_logloss: 0.0263707
# [1467]	training's binary_logloss: 3.13899e-05	valid_1's binary_logloss: 0.0263333
# [1468]	training's binary_logloss: 3.12479e-05	valid_1's binary_logloss: 0.0263136
# [1469]	training's binary_logloss: 3.1111e-05	valid_1's binary_logloss: 0.0262998
# [1470]	training's binary_logloss: 3.09749e-05	valid_1's binary_logloss: 0.0262706
# [1471]	training's binary_logloss: 3.08513e-05	valid_1's binary_logloss: 0.0262697
# [1472]	training's binary_logloss: 3.06919e-05	valid_1's binary_logloss: 0.0263309
# [1473]	training's binary_logloss: 3.05743e-05	valid_1's binary_logloss: 0.0263456
# [1474]	training's binary_logloss: 3.04529e-05	valid_1's binary_logloss: 0.0264193
# [1475]	training's binary_logloss: 3.0287e-05	valid_1's binary_logloss: 0.0263324
# [1476]	training's binary_logloss: 3.01571e-05	valid_1's binary_logloss: 0.0263274
# Early stopping, best iteration is:
# [1276]	training's binary_logloss: 8.48229e-05	valid_1's binary_logloss: 0.0254487

# %%
preds = model.predict(valid_X)
print("LGB dev f1_score:", f1_score(valid_y, np.round(preds)))
print("LGB dev accuracy_score:", accuracy_score(valid_y, np.round(preds)))
print("LGB dev recall_score:", recall_score(valid_y, np.round(preds)))
print("LGB dev precision_score:", precision_score(valid_y, np.round(preds)))
# Out:
# LGB dev f1_score: 0.9909090909090909
# LGB dev accuracy_score: 0.9933823529411765
# LGB dev recall_score: 0.9919110212335692
# LGB dev precision_score: 0.9899091826437941

# %%
print('Saving model...')
# save model to file
if not os.path.exists('data/models/'):
    os.makedirs('data/models/')

model.save_model('data/models/lgb_model_best_iter_5.txt', num_iteration=model.best_iteration)
print('Model Saved')
# Out:
# Saving model...
# Model Saved

# %%
print("Saving wb model")
with open('data/models/wb_transform_5.pkl', 'wb') as model_file:
    pkl.dump(wb, model_file, protocol=2)
print('Model Saved')
# Out:
# Saving wb model
# Model Saved

# %%
y_hat = model.predict(X_test)
pred = pd.DataFrame(np.round(y_hat).astype(int), columns=['label'])
pred['id'] = test_ids
pred.to_csv('data/kaggle/submission_lgb_simple_5.csv', index=False)
print('Kaggle Submission Saved to data/kaggle/')
# Out:
# Kaggle Submission Saved to data/kaggle/
